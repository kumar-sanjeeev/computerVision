# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
image = mpimg.imread('images/wa_state_highway.jpg')
plt.imshow(image)

# %%
print("Image Dimensions", image.shape)
# Out:
# Image Dimensions (3088, 4700, 3)

# %%
red = image[:,:,0]
green = image[:,:,1]
blue = image[:,:,2]

# %%
plt.subplot(1,3,1)
plt.imshow(red)
plt.title("Red Channels")
# Out:
# Text(0.5, 1.0, 'Red Channels')

# %%
f,(ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
ax1.set_title("Red channels")
ax1.imshow (red, cmap='gray')
ax2.set_title("Green channels")
ax2.imshow (red,cmap='gray')
ax3.set_title("Blue channels")
ax3.imshow (red,cmap='gray')
